# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5, 11)
y = x * x

# %%
x = np.linspace(0, 5, 50)
fig, ax = plt.subplots(figsize=(10, 8))
ax.plot(x, x**2, color='#FF008B', lw=2, alpha=0.5, ls='--')
ax.plot(x, x**3, 'r-*')

ax.set_xlim([0, 2])
ax.set_ylim([0, 10])
# Out:
# (0, 10)
