# %% [markdown]
# # Visualização de dados embutida ao Pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('ggplot')
# %matplotlib inline

# %%
df1 = pd.read_csv("df1", index_col=0)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 2000-01-01 to 2002-09-26
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       1000 non-null   float64
#  1   B       1000 non-null   float64
#  2   C       1000 non-null   float64
#  3   D       1000 non-null   float64
# dtypes: float64(4)
# memory usage: 39.1+ KB

# %%
df2 = pd.read_csv("df2")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       10 non-null     float64
#  1   b       10 non-null     float64
#  2   c       10 non-null     float64
#  3   d       10 non-null     float64
# dtypes: float64(4)
# memory usage: 448.0 bytes

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
df2.plot.area(alpha=0.4)
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist(bins=100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1.plot.line(figsize=(15, 5))
# Out:
# <AxesSubplot:>

# %%
df1.plot.scatter(x='A', y='B', c='C', cmap='inferno')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*20, cmap='inferno')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(1000, 2), columns=['A', 'B'])

# %%
df
# Out:
#             A         B
# 0    0.789168  0.735690
# 1    0.872559  0.762947
# 2    0.639715  0.682729
# 3    0.977810  0.900558
# 4    0.214981  0.694884
# ..        ...       ...
# 995  0.369008  0.264146
# 996  0.401463  0.007470
# 997  0.814675  0.153741
# 998  0.354633  0.762687
# 999  0.693091  0.855383
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='A', y='B', gridsize=20)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
