# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 5, 11)
y = x * x

# %%
fig, ax = plt.subplots(figsize=(8, 10))
ax.plot(x, x**2, color='#8B008B', linewidth=1, alpha=1, linestyle='--', marker='*')
ax.plot(x, x**3, color='blue')

ax.set_xlim([0, 2])
ax.set_ylim([0, 10])
# Out:
# (0.0, 10.0)
